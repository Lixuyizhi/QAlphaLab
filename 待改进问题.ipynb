# %% [markdown]
# # 回测框架问题

# %% [markdown]
# * 策略定义部分由于WeightStrategyBase本身的订单生成器是OrderGenWOInteract（详情见源码）所以在处理当天不可交易股票时并不会将可交易股票的目标仓位权重归一化导致资金闲置
# * 目前采取的解决方案是通过qlib当中的is_tradable函数 提前判断股票是否当天可交易 直接返回正确的权重字典
# * 后续应当重写其订单生成器种类 变为OrderGenWInteract从而支持可交易股票权重归一化
